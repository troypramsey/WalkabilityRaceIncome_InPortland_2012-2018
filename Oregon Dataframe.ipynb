# %%
import pandas as pd

maps_base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'

# %%
oregon_df = pd.read_csv(r'OR_Features_20200701.txt', sep='|')
oregon_df
# Out:
#        FEATURE_ID                             FEATURE_NAME FEATURE_CLASS  \
# 0          218009                               Agate Flat          Flat
# 1          218942                             Beaver Basin         Basin
# 2          220448                               Camp Creek        Stream
# 3          222880                   East Fork Beaver Creek        Stream
# 4          222978                               Edge Creek        Stream
# ...           ...                                      ...           ...
# 60166     2812896         Fairview Census Designated Place        Census
# 60167     2812897  Marlene Village Census Designated Place        Census
# 60168     2812898           Dilley Census Designated Place        Census
# 60169     2812899     Cherry Grove Census Designated Place        Census
# 60170     2813154                        Crew Canyon Creek        Stream
#
#       STATE_ALPHA  STATE_NUMERIC COUNTY_NAME  COUNTY_NUMERIC PRIMARY_LAT_DMS  \
# 0              OR             41     Jackson            29.0         420059N
# 1              CA              6    Siskiyou            93.0         420024N
# 2              CA              6    Siskiyou            93.0         415823N
# 3              CA              6    Siskiyou            93.0         415943N
# 4              CA              6    Siskiyou            93.0         415802N
# ...           ...            ...         ...             ...             ...
# 60166          OR             41   Tillamook            57.0         452730N
# 60167          OR             41  Washington            67.0         453102N
# 60168          OR             41  Washington            67.0         452930N
# 60169          OR             41  Washington            67.0         452703N
# 60170          OR             41       Curry            15.0         423441N
#
#       PRIM_LONG_DMS  PRIM_LAT_DEC  PRIM_LONG_DEC SOURCE_LAT_DMS  \
# 0          1222337W     42.016300    -122.393500            NaN
# 1          1221749W     42.006531    -122.296962            NaN
# 2          1222613W     41.972918    -122.436966        420331N
# 3          1221834W     41.995278    -122.309444        420104N
# 4          1221250W     41.967088    -122.213903        420220N
# ...             ...           ...            ...            ...
# 60166      1234733W     45.458328    -123.792589            NaN
# 60167      1224912W     45.517293    -122.819951            NaN
# 60168      1230720W     45.491714    -123.122270            NaN
# 60169      1231453W     45.450705    -123.248126            NaN
# 60170      1242021W     42.578020    -124.339100        423525N
#
#       SOURCE_LONG_DMS  SOURCE_LAT_DEC  SOURCE_LONG_DEC  ELEV_IN_M  ELEV_IN_FT  \
# 0                 NaN             NaN              NaN     1001.0      3284.0
# 1                 NaN             NaN              NaN      994.0      3261.0
# 2            1222837W       42.058749      -122.476968      710.0      2329.0
# 3            1221654W       42.017778      -122.281667      797.0      2615.0
# 4            1221319W       42.038753      -122.221960      809.0      2654.0
# ...               ...             ...              ...        ...         ...
# 60166             NaN             NaN              NaN        NaN         NaN
# 60167             NaN             NaN              NaN        NaN         NaN
# 60168             NaN             NaN              NaN        NaN         NaN
# 60169             NaN             NaN              NaN        NaN         NaN
# 60170        1242219W       42.590250      -124.371880        NaN         NaN
#
#                      MAP_NAME DATE_CREATED DATE_EDITED
# 0               Soda Mountain   01/19/1981  05/30/2007
# 1             Parker Mountain   01/19/1981         NaN
# 2         Iron Gate Reservoir   01/19/1981  07/03/2009
# 3                       Copco   01/19/1981  05/24/2007
# 4      Secret Spring Mountain   01/19/1981         NaN
# ...                       ...          ...         ...
# 60166               Tillamook   06/18/2020         NaN
# 60167                 Linnton   06/18/2020         NaN
# 60168              Laurelwood   06/18/2020         NaN
# 60169                  Gaston   06/18/2020         NaN
# 60170    Brushy Bald Mountain   07/06/2020         NaN
#
# [60171 rows x 20 columns]

# %%
multnomah_df = oregon_df.loc[oregon_df['COUNTY_NAME'] == 'Multnomah', :]

# %%
multnomah_feature_df = multnomah_df.loc[(multnomah_df['FEATURE_CLASS'] == 'Populated Place') 
                                        | (multnomah_df['FEATURE_CLASS'] == 'Area'), :]

# %%
multnomah_feature_df
# Out:
#        FEATURE_ID    FEATURE_NAME    FEATURE_CLASS STATE_ALPHA  STATE_NUMERIC  \
# 505       1116794         Alameda  Populated Place          OR             41
# 2033      1118331      Burlington  Populated Place          OR             41
# 2295      1118596    Capitol Hill  Populated Place          OR             41
# 5099      1121424         Gresham  Populated Place          OR             41
# 6427      1122763   Kings Heights  Populated Place          OR             41
# ...           ...             ...              ...         ...            ...
# 49163     1637845      Folkenberg  Populated Place          OR             41
# 49951     1638840  Barnes Heights  Populated Place          OR             41
# 50424     1639429    Maywood Park  Populated Place          OR             41
# 50600     1851708   Johns Landing  Populated Place          OR             41
# 50706     1867473       Hazelwood  Populated Place          OR             41
#
#       COUNTY_NAME  COUNTY_NUMERIC PRIMARY_LAT_DMS PRIM_LONG_DMS  PRIM_LAT_DEC  \
# 505     Multnomah            51.0         453318N      1223750W     45.555118
# 2033    Multnomah            51.0         453846N      1225033W     45.646227
# 2295    Multnomah            51.0         452755N      1224151W     45.465396
# 5099    Multnomah            51.0         452953N      1222553W     45.498176
# 6427    Multnomah            51.0         453145N      1224228W     45.529284
# ...           ...             ...             ...           ...           ...
# 49163   Multnomah            51.0         453744N      1225158W     45.629005
# 49951   Multnomah            51.0         453156N      1224514W     45.532340
# 50424   Multnomah            51.0         453310N      1223337W     45.552897
# 50600   Multnomah            51.0         452358N      1224029W     45.399564
# 50706   Multnomah            51.0         453059N      1223126W     45.516509
#
#        PRIM_LONG_DEC SOURCE_LAT_DMS SOURCE_LONG_DMS  SOURCE_LAT_DEC  \
# 505      -122.630651            NaN             NaN             NaN
# 2033     -122.842602            NaN             NaN             NaN
# 2295     -122.697596            NaN             NaN             NaN
# 5099     -122.431480            NaN             NaN             NaN
# 6427     -122.707875            NaN             NaN             NaN
# ...              ...            ...             ...             ...
# 49163    -122.866213            NaN             NaN             NaN
# 49951    -122.753987            NaN             NaN             NaN
# 50424    -122.560371            NaN             NaN             NaN
# 50600    -122.674816            NaN             NaN             NaN
# 50706    -122.523981            NaN             NaN             NaN
#
#        SOURCE_LONG_DEC  ELEV_IN_M  ELEV_IN_FT       MAP_NAME DATE_CREATED  \
# 505                NaN       73.0       239.0       Portland   11/28/1980
# 2033               NaN       22.0        72.0  Sauvie Island   11/28/1980
# 2295               NaN      144.0       472.0    Lake Oswego   11/28/1980
# 5099               NaN       97.0       318.0       Damascus   11/28/1980
# 6427               NaN      120.0       394.0       Portland   11/28/1980
# ...                ...        ...         ...            ...          ...
# 49163              NaN       48.0       157.0  Sauvie Island   11/28/1980
# 49951              NaN      279.0       915.0        Linnton   03/01/1994
# 50424              NaN       46.0       151.0    Mount Tabor   05/01/1994
# 50600              NaN      169.0       554.0    Lake Oswego   09/14/1999
# 50706              NaN       93.0       305.0    Mount Tabor   05/15/2000
#
#       DATE_EDITED
# 505           NaN
# 2033          NaN
# 2295          NaN
# 5099   03/21/2008
# 6427          NaN
# ...           ...
# 49163         NaN
# 49951         NaN
# 50424  03/21/2008
# 50600         NaN
# 50706  03/21/2008
#
# [84 rows x 20 columns]
